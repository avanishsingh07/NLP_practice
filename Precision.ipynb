# %%
Total_record = 80
retrieved = 60
relevant = 45

# %%
B = Total_record-relevant
C = retrieved-relevant

# %%
recall = relevant/(relevant+B)
print("Recall =",recall*100,"%")
# Out:
# Recall = 56.25 %

# %%
precision = relevant/(relevant+C)
print("Precision =",precision*100,"%")
# Out:
# Precision = 75.0 %
